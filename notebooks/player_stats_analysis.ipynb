# %%
import pandas as pd
import numpy as np

# Load the player stats data
df = pd.read_csv('../data/raw/player_stats.csv')

print(f"Dataset Shape: {df.shape[0]} players x {df.shape[1]} columns\n")
df

# %%
# Display basic information
print("Dataset Info:")
print(df.info())
print("\n" + "="*60)
print("\nBasic Statistics:")
df.describe()

# %%
# Show top 10 players by Col1 (appears to be rank/level)
print("Top 10 Players by Col1:")
df.nlargest(10, 'Col1')[['Player', 'Col1', 'Col2', 'Col3', 'Col5', 'Col6']]
